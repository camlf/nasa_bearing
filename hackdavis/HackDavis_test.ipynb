# %% [markdown]
# # HackDavis python library tests
#
# ## OCS-HackDavis Package Installation

# %%
# !pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ ocs-hackdavis==0.18.0
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# Requirement already satisfied: ocs-hackdavis==0.18.0 in /opt/conda/lib/python3.7/site-packages (0.18.0)
# Requirement already satisfied: typeguard>=2.4.1 in /opt/conda/lib/python3.7/site-packages (from ocs-hackdavis==0.18.0) (2.7.1)
# Requirement already satisfied: ocs-sample-library-preview==0.0.36rc0 in /opt/conda/lib/python3.7/site-packages (from ocs-hackdavis==0.18.0) (0.0.36rc0)
# Requirement already satisfied: requests==2.22.0 in /opt/conda/lib/python3.7/site-packages (from ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (2.22.0)
# Requirement already satisfied: python-dateutil==2.8.0 in /opt/conda/lib/python3.7/site-packages (from ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (2.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (1.25.6)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (2.8)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil==2.8.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.18.0) (1.13.0)

# %% [markdown]
# ## Import functions

# %%
from ocs_hackdavis import (
    ucdavis_buildings,
    ucdavis_ceeds_of,
    ucdavis_dataview_id,
    ucdavis_config_data,
)

# %% [markdown]
# ## List of buildings

# %%
buildings = ucdavis_buildings()
len(buildings), buildings[:25]
# Out:
# (162,
#  ['ARC Pavilion',
#   'Academic Surge Building',
#   'Activities and Recreation Center',
#   'Advanced Materials Research Laboratory',
#   'Advanced Transportation Infrastructure Research Center',
#   'Aggie Stadium',
#   'Agronomy Field Laboratory',
#   'Animal Building',
#   'Animal Resource Service J1',
#   'Animal Resource Service M3',
#   'Animal Resource Service N1',
#   'Ann E. Pitzer Center',
#   'Antique Mechanics Trailer',
#   'Aquatic Biology & Environmental Science Bldg',
#   'Art Building',
#   'Art Building Annex',
#   'Art, Music, Wright Halls',
#   'Asmundson Annex',
#   'Asmundson Hall',
#   'Bainer Hall',
#   'Bowley Head House',
#   'Briggs Hall',
#   'California Hall',
#   'Campus Data Center',
#   'Cellular Biology Laboratory'])

# %% [markdown]
# ## Function `ucdavis_ceeds_of` returns list of CEEDs for a given building
#
# ### Display them for all buildings

# %%
for num, building in enumerate(ucdavis_buildings(), 1):
    print(f"[{num}] Building: {building} ==> CEEDS: {ucdavis_ceeds_of(building)}")
# Out:
# [1] Building: ARC Pavilion ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [2] Building: Academic Surge Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [3] Building: Activities and Recreation Center ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [4] Building: Advanced Materials Research Laboratory ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [5] Building: Advanced Transportation Infrastructure Research Center ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [6] Building: Aggie Stadium ==> CEEDS: ['Electricity']
# [7] Building: Agronomy Field Laboratory ==> CEEDS: ['Electricity']
# [8] Building: Animal Building ==> CEEDS: ['Electricity']
# [9] Building: Animal Resource Service J1 ==> CEEDS: ['Electricity', 'Natural Gas']
# [10] Building: Animal Resource Service M3 ==> CEEDS: ['Electricity']
# [11] Building: Animal Resource Service N1 ==> CEEDS: ['Electricity']
# [12] Building: Ann E. Pitzer Center ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [13] Building: Antique Mechanics Trailer ==> CEEDS: ['Electricity']
# [14] Building: Aquatic Biology & Environmental Science Bldg ==> CEEDS: ['Electricity']
# [15] Building: Art Building ==> CEEDS: ['Electricity']
# [16] Building: Art Building Annex ==> CEEDS: ['Electricity']
# [17] Building: Art, Music, Wright Halls ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [18] Building: Asmundson Annex ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [19] Building: Asmundson Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [20] Building: Bainer Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [21] Building: Bowley Head House ==> CEEDS: ['Electricity']
# [22] Building: Briggs Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [23] Building: California Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [24] Building: Campus Data Center ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity']
# [25] Building: Cellular Biology Laboratory ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [26] Building: Center for Companion Animal Health ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [27] Building: Center for Comparative Medicine ==> CEEDS: ['Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [28] Building: Center for Health & Environment Clinical Medicine ==> CEEDS: ['Electricity']
# [29] Building: Center for Health & Environment Office & Laboratory ==> CEEDS: ['Electricity']
# [30] Building: Center for Health & Environment Toxic Pollutant Laboratory ==> CEEDS: ['Baseline Electricity', 'Electricity', 'Natural Gas']
# [31] Building: Central Cage Wash Facility ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [32] Building: Chemistry ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [33] Building: Chemistry Annex ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [34] Building: Cole A ==> CEEDS: ['Electricity']
# [35] Building: Cole B ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [36] Building: Conference Center ==> CEEDS: ['Electricity']
# [37] Building: Contained Research Facility ==> CEEDS: ['Electricity']
# [38] Building: Cruess Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [39] Building: Dairy Cattle Feed ==> CEEDS: ['Electricity']
# [40] Building: Dairy Cattle Shed ==> CEEDS: ['Electricity']
# [41] Building: Dairy Tower ==> CEEDS: ['Electricity']
# [42] Building: Dutton Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [43] Building: Earth and Physical Sciences Building ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [44] Building: Environmental Services Facility Headquarters ==> CEEDS: ['Electricity']
# [45] Building: Equestrian Center Caretaker Trailer ==> CEEDS: ['Electricity']
# [46] Building: Equestrian Center Covered Arena ==> CEEDS: ['Electricity']
# [47] Building: Everson Hall ==> CEEDS: ['Electricity', 'Steam']
# [48] Building: FPS Trinchero Building ==> CEEDS: ['Baseline Gas', 'Electricity', 'NaturalGas']
# [49] Building: Facilities Electrical Annex ==> CEEDS: ['Electricity']
# [50] Building: Freeborn Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [51] Building: Gallagher Hall ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [52] Building: Gateway Parking Structure ==> CEEDS: ['Electricity']
# [53] Building: Genome & Biomedical Sciences Facility ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [54] Building: Geotechnical Modeling Facility ==> CEEDS: ['Electricity']
# [55] Building: Ghausi Hall ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [56] Building: Giedt Hall ==> CEEDS: ['Baseline ChilledWater', 'ChilledWater', 'Electricity', 'Steam']
# [57] Building: Gourley Clinical Teaching Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [58] Building: Growth Chamber Building T1 ==> CEEDS: ['Electricity']
# [59] Building: Growth Chamber Building T2 ==> CEEDS: ['Electricity']
# [60] Building: Haring Hall ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [61] Building: Hart Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [62] Building: Heitman Staff Learning Center ==> CEEDS: ['Electricity', 'Gas']
# [63] Building: Hickey Gym ==> CEEDS: ['Electricity', 'Steam']
# [64] Building: Hickey Pool ==> CEEDS: ['Baseline Electricity', 'Condensate', 'Electricity', 'Steam']
# [65] Building: Hoagland Hall ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [66] Building: Hopkins Services Center Parking Lot ==> CEEDS: ['Electricity']
# [67] Building: Hopkins Services Complex ==> CEEDS: ['Electricity']
# [68] Building: Hopkins Services Complex Auxiliary Receiving ==> CEEDS: ['Electricity']
# [69] Building: Housing Administration ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity']
# [70] Building: Hunt Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [71] Building: Hutchison Child Development Center ==> CEEDS: ['Electricity', 'Natural Gas']
# [72] Building: Hutchison Hall ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [73] Building: Hutchison Recreation Field Lights ==> CEEDS: ['Electricity']
# [74] Building: IET Communications Resources ==> CEEDS: ['Electricity']
# [75] Building: International Center ==> CEEDS: ['Electricity', 'Gas']
# [76] Building: Jackson Sustainable Winery ==> CEEDS: ['Electricity']
# [77] Building: Jungerman Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [78] Building: Kemper Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [79] Building: Kerr Hall ==> CEEDS: ['Baseline Electricity', 'Electricity', 'Steam']
# [80] Building: King Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity']
# [81] Building: Leukemia Barn ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [82] Building: Leukemia Lab ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [83] Building: Life Sciences ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [84] Building: Maddy Lab ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity']
# [85] Building: Mann Laboratory ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [86] Building: Mathematical Sciences Building ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [87] Building: Medical Sciences I B ==> CEEDS: ['Electricity']
# [88] Building: Medical Sciences I D ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [89] Building: Memorial Union ==> CEEDS: ['Baseline ChilledWater', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [90] Building: Meyer Hall ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [91] Building: Mrak Hall ==> CEEDS: ['Baseline ChilledWater', 'ChilledWater', 'Electricity', 'Steam']
# [92] Building: Music Building ==> CEEDS: ['Electricity']
# [93] Building: Office of Research (1850 Research Park Drive) ==> CEEDS: ['Electricity']
# [94] Building: Olson Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [95] Building: PES Tennis Courts ==> CEEDS: ['Electricity']
# [96] Building: Parsons Seed Certification Center ==> CEEDS: ['Electricity']
# [97] Building: Pavilion Parking Structure ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [98] Building: Physical Sciences & Engineering Library ==> CEEDS: ['Electricity']
# [99] Building: Physics Building ==> CEEDS: ['Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [100] Building: Plant & Environmental Sciences ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [101] Building: Plant Reproductive Biology Facility ==> CEEDS: ['Electricity']
# [102] Building: Primate Childhood Health & Disease Facility ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [103] Building: Primate Controlled Environment Facility (CEF) ==> CEEDS: ['Electricity']
# [104] Building: Primate Quarantine ==> CEEDS: ['Electricity']
# [105] Building: Primate Respiratory Disease Center ==> CEEDS: ['Baseline Electricity', 'Electricity', 'Natural Gas']
# [106] Building: Primate Shop Facility ==> CEEDS: ['Electricity']
# [107] Building: Primate Virology & Immunology Laboratory ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [108] Building: Pritchard VMTH ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [109] Building: Quad Parking Structure ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [110] Building: RMI Brewery, Winery, and Food Pilot Facility ==> CEEDS: ['Baseline ChilledWater', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [111] Building: Roessler Hall ==> CEEDS: ['ChilledWater', 'Electricity']
# [112] Building: Schaal Aquatic Center ==> CEEDS: ['Baseline Electricity', 'Electricity', 'Steam']
# [113] Building: School of Education Building ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity']
# [114] Building: Sciences Lab Building ==> CEEDS: ['Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [115] Building: Segundo Dining Commons ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [116] Building: Segundo High Rises ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [117] Building: Segundo Regan ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [118] Building: Segundo Services Center ==> CEEDS: ['Baseline ChilledWater', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [119] Building: Shields Library ==> CEEDS: ['Baseline ChilledWater', 'ChilledWater', 'Electricity', 'Steam']
# [120] Building: Shrem Museum of Art ==> CEEDS: ['Baseline ChilledWater', 'Baseline Gas', 'ChilledWater', 'Electricity', 'Gas']
# [121] Building: Silo Bike Barn ==> CEEDS: ['Electricity']
# [122] Building: Social Sciences & Humanities ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [123] Building: Sprocket Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [124] Building: Sproul Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [125] Building: Storer Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [126] Building: Student Affairs Annex ==> CEEDS: ['Electricity']
# [127] Building: Student Community Center ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [128] Building: Student Health & Wellness Center ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [129] Building: Swine Teaching and Research Facility ==> CEEDS: ['Electricity']
# [130] Building: TAPS C&E ==> CEEDS: ['Electricity']
# [131] Building: Temporary Building 144 ==> CEEDS: ['Electricity']
# [132] Building: Temporary Building 178 ==> CEEDS: ['Electricity']
# [133] Building: Temporary Building 184 ==> CEEDS: ['Electricity']
# [134] Building: Tercero 1 ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [135] Building: Tercero 2 ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [136] Building: Tercero 3 ==> CEEDS: ['Baseline ChilledWater', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [137] Building: Tercero 4 ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [138] Building: Tercero Dining Commons ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Heating']
# [139] Building: The Barn ==> CEEDS: ['Electricity']
# [140] Building: The Grove ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [141] Building: Thurman Laboratory ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [142] Building: Translational Shared Research Facility ==> CEEDS: ['Electricity']
# [143] Building: Transportation and Parking Services ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Gas', 'ChilledWater', 'Electricity', 'Natural Gas']
# [144] Building: Tupper Hall ==> CEEDS: ['Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [145] Building: University Extension Building ==> CEEDS: ['Electricity']
# [146] Building: VMTH Surgical ==> CEEDS: ['Electricity']
# [147] Building: VMTH Ward ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [148] Building: Valley Hall ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [149] Building: Vet Med Equine Athletic Performance Lab ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [150] Building: Vet Med Lab Animal A Beach Lab ==> CEEDS: ['Electricity']
# [151] Building: Vet Med Large Animal Facility ==> CEEDS: ['Electricity']
# [152] Building: Vet Med Student Services and Administration Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [153] Building: Veterinary Medicine 2 ==> CEEDS: ['Baseline Electricity', 'Electricity', 'Steam']
# [154] Building: Voorhies Hall ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [155] Building: Walker Hall ==> CEEDS: ['Electricity']
# [156] Building: Water Science & Engineering Hydraulic L2 ==> CEEDS: ['Electricity']
# [157] Building: Watershed Science Facility ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [158] Building: Wellman Hall ==> CEEDS: ['Baseline Electricity', 'ChilledWater', 'Electricity', 'Steam']
# [159] Building: Western Human Nutrition Research Center (WHNRC) ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [160] Building: Wickson Hall ==> CEEDS: ['Baseline ChilledWater', 'Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']
# [161] Building: Wright Hall ==> CEEDS: ['Baseline Electricity', 'Electricity']
# [162] Building: Young Hall ==> CEEDS: ['Baseline Electricity', 'Baseline Steam', 'ChilledWater', 'Electricity', 'Steam']

# %% [markdown]
# ## Test error code
#
# ### Bad argument of the right type

# %%
# should fail
ucdavis_ceeds_of("Bad Building")
# Out:
# #warning: "Bad Building" is not a valid building name

# %% [markdown]
# ## Bad argument type

# %%
# should fail - type error
ucdavis_ceeds_of(42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a3d700bd5660> in <module>
#       1 # should fail - type error
# ----> 2 ucdavis_ceeds_of(42)
#
# /opt/conda/lib/python3.7/site-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#     807     def wrapper(*args, **kwargs):
#     808         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
# --> 809         check_argument_types(memo)
#     810         retval = func(*args, **kwargs)
#     811         check_return_type(retval, memo)
#
# /opt/conda/lib/python3.7/site-packages/typeguard/__init__.py in check_argument_types(memo)
#     668                 check_type(description, value, expected_type, memo)
#     669             except TypeError as exc:  # suppress unnecessarily long tracebacks
# --> 670                 raise exc from None
#     671
#     672     return True
#
# /opt/conda/lib/python3.7/site-packages/typeguard/__init__.py in check_argument_types(memo)
#     666             description = 'argument "{}"'.format(argname)
#     667             try:
# --> 668                 check_type(description, value, expected_type, memo)
#     669             except TypeError as exc:  # suppress unnecessarily long tracebacks
#     670                 raise exc from None
#
# /opt/conda/lib/python3.7/site-packages/typeguard/__init__.py in check_type(argname, value, expected_type, memo)
#     596                 raise TypeError(
#     597                     'type of {} must be {}; got {} instead'.
# --> 598                     format(argname, qualified_name(expected_type), qualified_name(value)))
#     599     elif isinstance(expected_type, TypeVar):
#     600         # Only happens on < 3.6
#
# TypeError: type of argument "building" must be str; got int instead

# %% [markdown]
# ## Get Data View ID of a given building+CEED pair

# %%
dv_id = ucdavis_dataview_id("Activities and Recreation Center", "Electricity")
dv_id
# Out:
# 'hackdavis_9747d9db'

# %% [markdown]
# ## Import for OCS Sample Library and other necessary modules

# %%
from ocs_sample_library_preview import OCSClient
import configparser
import io
import json
import pandas as pd

# %% [markdown]
# ## Standard configuration file parsing and OCS client object
#
# #### Reference: https://github.com/osisoft/OSI-Samples-OCS/blob/master/basic_samples/DataViews/Python3/program.py#L150
#
# ## IMPORTANT: REPLACE CLIENT ID + SECRET BELOW BEFORE RUNNING

# %%
config_text = u"""
; IMPORTANT: replace these values with those provided by OSIsoft
[Configurations]
Namespace = UC__Davis

[Access]
Resource = https://dat-b.osisoft.com
Tenant = 65292b6c-ec16-414a-b583-ce7ae04046d4
ApiVersion = v1-preview

[Credentials]
ClientId = REPLACE_ME
ClientSecret = REPLACE_ME
"""

# %%
config = configparser.ConfigParser(allow_no_value=True)
config.read_file(io.StringIO(config_text))

ocs_client = OCSClient(
    config.get("Access", "ApiVersion"),
    config.get("Access", "Tenant"),
    config.get("Access", "Resource"),
    config.get("Credentials", "ClientId"),
    config.get("Credentials", "ClientSecret"),
)

namespace_id = config.get("Configurations", "Namespace")
print(f"namespace_id: '{namespace_id}'")
# Out:
# ---------------------------------------------------------------------------
# SdsError                                  Traceback (most recent call last)
# <ipython-input-26-b8f606165fbe> in <module>
#       7     config.get("Access", "Resource"),
#       8     config.get("Credentials", "ClientId"),
# ----> 9     config.get("Credentials", "ClientSecret"),
#      10 )
#      11
#
# /opt/conda/lib/python3.7/site-packages/ocs_sample_library_preview/OCSClient.py in __init__(self, apiversion, tenant, url, clientId, clientSecret, acceptVerbosity)
#      23         """
#      24         self.__baseClient = BaseClient(apiversion, tenant, url, clientId,
# ---> 25                                        clientSecret, acceptVerbosity)
#      26         self.__DataViews = DataViews(self.__baseClient)
#      27         self.__Types = Types(self.__baseClient)
#
# /opt/conda/lib/python3.7/site-packages/ocs_sample_library_preview/BaseClient.py in __init__(self, apiversion, tenant, url, clientId, clientSecret, acceptVerbosity)
#      23         self.__token = ""
#      24         self.__expiration = 0
# ---> 25         self.__getToken()
#      26         self.__acceptVerbosity = acceptVerbosity
#      27         self.__requestTimeout = None
#
# /opt/conda/lib/python3.7/site-packages/ocs_sample_library_preview/BaseClient.py in __getToken(self)
#     109         if expiration is None:
#     110             raise SdsError(
# --> 111                 f"Failed to get token, check client id/secret: {token['error']}")
#     112
#     113         self.__expiration = float(expiration) + time.time()
#
# SdsError: 'Failed to get token, check client id/secret: invalid_client'

# %% [markdown]
# ## Getting CSV data from Data View

# %%
# Step 1) get data view id
dv_id = ucdavis_dataview_id("Activities and Recreation Center", "Electricity")

# Step 2) call data view
csv, token = ocs_client.DataViews.getDataInterpolated(
    namespace_id,
    dv_id,
    startIndex="2018-01-01",
    endIndex="2018-05-01",
    interval="00:20:00",
    count=250000,
    form="csvh",
)
# make sure there is no additional data
assert token is None

# display result subset
print(len(csv), csv[:2048])
# Out:
# 1307501 Timestamp,Building,CEED,Demand_kBtu,Electricity_EUI,MonthlyUsage,Cumulative Use,Demand,AnnualUsage,Rollover Check,Rollover Count Year,Rollover Count Month,AnnualCost,EUI
# 2018-01-01T00:00:00.0000000Z,Activities and Recreation Center,Electricity,482.0144,42.8698,484380.3,5538609.89475807,141.212522525084,6773462,0,0,0,,
# 2018-01-01T00:20:00.0000000Z,Activities and Recreation Center,Electricity,484.548,42.86924,484533.3,5538657.99972426,142.012899645591,6773400,0,0,0,,
# 2018-01-01T00:40:00.0000000Z,Activities and Recreation Center,Electricity,514.763,42.86868,484686.3,5538706.10469045,150.868408203125,6773337,0,0,0,,
# 2018-01-01T01:00:00.0000000Z,Activities and Recreation Center,Electricity,517.5825,42.86811,484839.3,5538755.10315018,151.694748312057,6773275,0,0,0,,
# 2018-01-01T01:20:00.0000000Z,Activities and Recreation Center,Electricity,524.0535,42.86755,484992.4,5538806.13010686,153.622489675805,6773213,0,0,0,,
# 2018-01-01T01:40:00.0000000Z,Activities and Recreation Center,Electricity,521.7031,42.86699,485145.4,5538857.15706354,152.902422746866,6773151,0,0,0,,
# 2018-01-01T02:00:00.0000000Z,Activities and Recreation Center,Electricity,524.3206,42.86642,485298.4,5538908.18402021,153.558167012265,6773089,0,0,0,,
# 2018-01-01T02:20:00.0000000Z,Activities and Recreation Center,Electricity,518.4031,42.86586,485451.4,5538959.21097689,151.935272216797,6773027,0,0,0,,
# 2018-01-01T02:40:00.0000000Z,Activities and Recreation Center,Electricity,525.5363,42.8653,485604.4,5539010.23793357,153.976598067229,6772965,0,0,0,,
# 2018-01-01T03:00:00.0000000Z,Activities and Recreation Center,Electricity,523.0957,42.86473,485757.4,5539061.55242993,153.310588867531,6772903,0,0,0,,
# 2018-01-01T03:20:00.0000000Z,Activities and Recreation Center,Electricity,519.0464,42.86417,485910.5,5539112.74892275,152.123809814453,6772841,0,0,0,,
# 2018-01-01T03:40:00.0000000Z,Activities and Recreation Center,Electricity,525.1151,42.86361,486063.5,5539161.61974449,153.90242116388,6772778,0,0,0,,
# 2018-01-01T04:00:00.0000000Z,Activities and Recreation Cen

# %% [markdown]
# ## Getting a Pandas dataframe from CSV

# %%
# Step 3) transform CSV into a Pandas dataframe, convert Timestamp column to the right data type
df = pd.read_csv(io.StringIO(csv), parse_dates=['Timestamp'])
df
# Out:
#                      Timestamp                          Building         CEED  \
# 0    2018-01-01 00:00:00+00:00  Activities and Recreation Center  Electricity
# 1    2018-01-01 00:20:00+00:00  Activities and Recreation Center  Electricity
# 2    2018-01-01 00:40:00+00:00  Activities and Recreation Center  Electricity
# 3    2018-01-01 01:00:00+00:00  Activities and Recreation Center  Electricity
# 4    2018-01-01 01:20:00+00:00  Activities and Recreation Center  Electricity
# ...                        ...                               ...          ...
# 8636 2018-04-30 22:40:00+00:00  Activities and Recreation Center  Electricity
# 8637 2018-04-30 23:00:00+00:00  Activities and Recreation Center  Electricity
# 8638 2018-04-30 23:20:00+00:00  Activities and Recreation Center  Electricity
# 8639 2018-04-30 23:40:00+00:00  Activities and Recreation Center  Electricity
# 8640 2018-05-01 00:00:00+00:00  Activities and Recreation Center  Electricity
#
#       Demand_kBtu  Electricity_EUI  MonthlyUsage  Cumulative Use      Demand  \
# 0        482.0144         42.86980      484380.3    5.538610e+06  141.212523
# 1        484.5480         42.86924      484533.3    5.538658e+06  142.012900
# 2        514.7630         42.86868      484686.3    5.538706e+06  150.868408
# 3        517.5825         42.86811      484839.3    5.538755e+06  151.694748
# 4        524.0535         42.86755      484992.4    5.538806e+06  153.622490
# ...           ...              ...           ...             ...         ...
# 8636     879.9150         41.69452      552921.9    6.159769e+06  262.015037
# 8637     879.9156         41.69426      553185.9    6.159858e+06  258.040084
# 8638     879.9163         41.69400      553449.8    6.159947e+06  271.704426
# 8639     879.9169         41.69374      553713.8    6.160035e+06  267.195156
# 8640     879.9175         41.69349      553977.6    6.160124e+06  266.432746
#
#       AnnualUsage  Rollover Check  Rollover Count Year  Rollover Count Month  \
# 0         6773462               0                    0                   0.0
# 1         6773400               0                    0                   0.0
# 2         6773337               0                    0                   0.0
# 3         6773275               0                    0                   0.0
# 4         6773213               0                    0                   0.0
# ...           ...             ...                  ...                   ...
# 8636      6591898               0                    0                   0.0
# 8637      6591902               0                    0                   0.0
# 8638      6591906               0                    0                   0.0
# 8639      6591910               0                    0                   0.0
# 8640      6591914               0                    0                   0.0
#
#       AnnualCost  EUI
# 0            NaN  NaN
# 1            NaN  NaN
# 2            NaN  NaN
# 3            NaN  NaN
# 4            NaN  NaN
# ...          ...  ...
# 8636         NaN  NaN
# 8637         NaN  NaN
# 8638         NaN  NaN
# 8639         NaN  NaN
# 8640         NaN  NaN
#
# [8641 rows x 14 columns]

# %%
# Same as above but keep only a subset of the columns
df_select = pd.read_csv(
    io.StringIO(csv),
    parse_dates=["Timestamp"],
    usecols=[
        "Timestamp",
        "AnnualUsage",
        "Cumulative Use",
        "Demand_kBtu",
        "Electricity_EUI",
        "MonthlyUsage",
    ],
)
df_select
# Out:
#                      Timestamp  Demand_kBtu  Electricity_EUI  MonthlyUsage  \
# 0    2018-01-01 00:00:00+00:00     482.0144         42.86980      484380.3
# 1    2018-01-01 00:20:00+00:00     484.5480         42.86924      484533.3
# 2    2018-01-01 00:40:00+00:00     514.7630         42.86868      484686.3
# 3    2018-01-01 01:00:00+00:00     517.5825         42.86811      484839.3
# 4    2018-01-01 01:20:00+00:00     524.0535         42.86755      484992.4
# ...                        ...          ...              ...           ...
# 8636 2018-04-30 22:40:00+00:00     879.9150         41.69452      552921.9
# 8637 2018-04-30 23:00:00+00:00     879.9156         41.69426      553185.9
# 8638 2018-04-30 23:20:00+00:00     879.9163         41.69400      553449.8
# 8639 2018-04-30 23:40:00+00:00     879.9169         41.69374      553713.8
# 8640 2018-05-01 00:00:00+00:00     879.9175         41.69349      553977.6
#
#       Cumulative Use  AnnualUsage
# 0       5.538610e+06      6773462
# 1       5.538658e+06      6773400
# 2       5.538706e+06      6773337
# 3       5.538755e+06      6773275
# 4       5.538806e+06      6773213
# ...              ...          ...
# 8636    6.159769e+06      6591898
# 8637    6.159858e+06      6591902
# 8638    6.159947e+06      6591906
# 8639    6.160035e+06      6591910
# 8640    6.160124e+06      6591914
#
# [8641 rows x 6 columns]

# %% [markdown]
# ## Access AF configuration data for a building+CEED pair
#
# ### Example

# %%
ucdavis_config_data(ocs_client, namespace_id, "Activities and Recreation Center", "Electricity")
# Out:
# {'Annual Cost': 151156.0,
#  'BuildingName': 'ARC',
#  'kWh Rate': 0.0687,
#  'Prefix': 'Activities_and_Recreation_Center_MSB',
#  'Rollover': 10000000.0,
#  'CAAN': 4799.0,
#  'Construction Date': '04/15/2002',
#  'Display Name': 'Activities and Recreation Center',
#  'Latitude': 38.5428969596,
#  'Longitude': -121.759644393,
#  'Maintained Gross Sq. Ft.': 158120.0,
#  'Primary Usage (Type)': 'REC - Athletics & Recreation'}

# %% [markdown]
# #### Note: each CEED of a building has a copy of the AF configuration data of the parent element (e.g. BuildingName, Latitude, Longitude, etc)

# %%
ucdavis_config_data(ocs_client, namespace_id, "Activities and Recreation Center", "Steam")
# Out:
# {'Annual Cost': 46360.0,
#  'BuildingName': 'ARC',
#  'klb Rate': 7.2552,
#  'Prefix': 'Activities_and_Recreation_Center_MSB',
#  'Rollover': 100000.0,
#  'Rollover Count Month': 0.0,
#  'Rollover Count Year': 0.0,
#  'CAAN': 4799.0,
#  'Construction Date': '04/15/2002',
#  'Display Name': 'Activities and Recreation Center',
#  'Latitude': 38.5428969596,
#  'Longitude': -121.759644393,
#  'Maintained Gross Sq. Ft.': 158120.0,
#  'Primary Usage (Type)': 'REC - Athletics & Recreation'}

# %% [markdown]
# ## Display AF configuration data of 10 first building+CEEDs

# %%
count = 1
for building in ucdavis_buildings():
    for ceed in ucdavis_ceeds_of(building):
        print(
            f"[{count}] {building} | {ceed}\n  {ucdavis_config_data(ocs_client, namespace_id, building, ceed)}"
        )
        count += 1
        print("------------------------")
    if count >= 10:
        break
# Out:
# [1] ARC Pavilion | Baseline Electricity
#   {'Building Name': 'ARCPavilion', 'CDD Coefficient': -0.48, 'CDD^2 Coefficient': 0.03, 'HDD Coefficient': 1.34, 'HDD^2 Coefficient': -0.06, 'Intercept Coefficient': 279.71, 'MONTH 1 Coefficient': 32.25, 'MONTH 10 Coefficient': -8.3, 'MONTH 11 Coefficient': -1.69, 'MONTH 2 Coefficient': 24.78, 'MONTH 3 Coefficient': -25.79, 'MONTH 4 Coefficient': -26.2, 'MONTH 5 Coefficient': -42.44, 'MONTH 6 Coefficient': -4.45, 'MONTH 7 Coefficient': -39.21, 'MONTH 8 Coefficient': 11.07, 'MONTH 9 Coefficient': -23.57, 'Outlier High': '', 'Outlier Low': '', 'Predicted EUI': '', 'Predicted EUI Outlier High': '', 'Predicted EUI Outlier Low': '', 'TOD 0 Coefficient': -33.44, 'TOD 1 Coefficient': -33.42, 'TOD 10 Coefficient': 43.45, 'TOD 11 Coefficient': 44.09, 'TOD 12 Coefficient': 43.51, 'TOD 13 Coefficient': 41.74, 'TOD 14 Coefficient': 40.41, 'TOD 15 Coefficient': 38.26, 'TOD 16 Coefficient': 36.35, 'TOD 17 Coefficient': 36.12, 'TOD 18 Coefficient': 37.68, 'TOD 19 Coefficient': 40.98, 'TOD 2 Coefficient': -34.04, 'TOD 20 Coefficient': 13.2, 'TOD 21 Coefficient': 1.88, 'TOD 22 Coefficient': 2.09, 'TOD 3 Coefficient': -34.04, 'TOD 4 Coefficient': -31.32, 'TOD 5 Coefficient': 32.18, 'TOD 6 Coefficient': 38.35, 'TOD 7 Coefficient': 39.49, 'TOD 8 Coefficient': 42.19, 'TOD 9 Coefficient': 41.95, 'WEEKEND Coefficient': -2.64, 'BuildingName': 'ARCPavilion', 'CAAN': 4444.0, 'Construction Date': '03/01/1977', 'Display Name': 'ARC Pavilion', 'Latitude': 38.54181213318, 'Longitude': -121.75962444, 'Maintained Gross Sq. Ft.': 171940.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [2] ARC Pavilion | ChilledWater
#   {'Annual Cost': 557.0, 'BuildingName': 'ARCPavilion', 'Prefix': 'ARC_Pavilion_Flexim', 'Rollover': 0.0, 'Rollover Count Month': 0.0, 'Rollover Count Year': 0.0, 'tonh Rate': 0.1493, 'CAAN': 4444.0, 'Construction Date': '03/01/1977', 'Display Name': 'ARC Pavilion', 'Latitude': 38.54181213318, 'Longitude': -121.75962444, 'Maintained Gross Sq. Ft.': 171940.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [3] ARC Pavilion | Electricity
#   {'Annual Cost': 51155.0, 'BuildingName': 'ARCPavilion', 'kWh Rate': 0.0687, 'Prefix': 'ARC_Pavilion', 'Rollover': 10000000.0, 'CAAN': 4444.0, 'Construction Date': '03/01/1977', 'Display Name': 'ARC Pavilion', 'Latitude': 38.54181213318, 'Longitude': -121.75962444, 'Maintained Gross Sq. Ft.': 171940.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [4] ARC Pavilion | Steam
#   {'Annual Cost': 1500.0, 'BuildingName': 'ARCPavilion', 'klb Rate': 7.2552, 'Prefix': 'ARC_Pavilion', 'Rollover': 0.0, 'Rollover Count Month': 0.0, 'Rollover Count Year': 0.0, 'CAAN': 4444.0, 'Construction Date': '03/01/1977', 'Display Name': 'ARC Pavilion', 'Latitude': 38.54181213318, 'Longitude': -121.75962444, 'Maintained Gross Sq. Ft.': 171940.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [5] Academic Surge Building | ChilledWater
#   {'Annual Cost': 712.0, 'BuildingName': 'AcademicSurge', 'Prefix': 'Academic_Surge_Building_Flexim', 'Rollover': 0.0, 'Rollover Count Month': 0.0, 'Rollover Count Year': 0.0, 'tonh Rate': 0.1493, 'CAAN': 4632.0, 'Construction Date': '05/01/1992', 'Display Name': 'Academic Surge Building', 'Latitude': 38.53530193195, 'Longitude': -121.752910499, 'Maintained Gross Sq. Ft.': 127426.0, 'Primary Usage (Type)': 'OFF - Academic / Administrative Office'}
# ------------------------
# [6] Academic Surge Building | Electricity
#   {'Annual Cost': 153550.0, 'BuildingName': 'AcademicSurge', 'kWh Rate': 0.0687, 'Prefix': 'Academic_Surge_Building_TOTAL', 'Rollover': 10000000.0, 'CAAN': 4632.0, 'Construction Date': '05/01/1992', 'Display Name': 'Academic Surge Building', 'Latitude': 38.53530193195, 'Longitude': -121.752910499, 'Maintained Gross Sq. Ft.': 127426.0, 'Primary Usage (Type)': 'OFF - Academic / Administrative Office'}
# ------------------------
# [7] Academic Surge Building | Steam
#   {'Annual Cost': 6360.0, 'BuildingName': 'AcademicSurge', 'klb Rate': 7.2552, 'Prefix': 'Academic_Surge_Building_Transformer_A', 'Rollover': 0.0, 'Rollover Count Month': 0.0, 'Rollover Count Year': 0.0, 'CAAN': 4632.0, 'Construction Date': '05/01/1992', 'Display Name': 'Academic Surge Building', 'Latitude': 38.53530193195, 'Longitude': -121.752910499, 'Maintained Gross Sq. Ft.': 127426.0, 'Primary Usage (Type)': 'OFF - Academic / Administrative Office'}
# ------------------------
# [8] Activities and Recreation Center | Baseline ChilledWater
#   {'Building Name': 'ARC', 'CDD Coefficient': 134.670083084168, 'CDD^2 Coefficient': -0.6868925064601, 'HDD Coefficient': -33.4140133130435, 'HDD^2 Coefficient': 1.29515136765919, 'Intercept Coefficient': -46.215478, 'MONTH 1 Coefficient': 25.2539554211591, 'MONTH 10 Coefficient': 46.0294366955786, 'MONTH 11 Coefficient': 128.872692202231, 'MONTH 2 Coefficient': 170.509137774326, 'MONTH 3 Coefficient': 183.67132613047, 'MONTH 4 Coefficient': 149.552559794571, 'MONTH 5 Coefficient': -67.8072705534682, 'MONTH 6 Coefficient': 155.801526151422, 'MONTH 7 Coefficient': 464.095044775692, 'MONTH 8 Coefficient': 186.27365877619, 'MONTH 9 Coefficient': 135.13077142009, 'Outlier High': 0.0, 'Outlier Low': 0.0, 'Predicted EUI': 0.0, 'Predicted EUI Outlier High': 0.0, 'Predicted EUI Outlier Low': 0.0, 'TOD 0 Coefficient': -73.4526697598208, 'TOD 1 Coefficient': -97.375094386848, 'TOD 10 Coefficient': -124.576001132207, 'TOD 11 Coefficient': -101.952393517949, 'TOD 12 Coefficient': -87.5255087058813, 'TOD 13 Coefficient': 58.8846651257137, 'TOD 14 Coefficient': 26.7955978450363, 'TOD 15 Coefficient': 54.8320262295017, 'TOD 16 Coefficient': 75.3232279206131, 'TOD 17 Coefficient': 182.71656529632, 'TOD 18 Coefficient': 275.143712360928, 'TOD 19 Coefficient': 315.325714915419, 'TOD 2 Coefficient': 301.3223384652, 'TOD 20 Coefficient': 285.60633391919, 'TOD 21 Coefficient': 265.165453963538, 'TOD 22 Coefficient': 226.025335071963, 'TOD 3 Coefficient': 222.402457010702, 'TOD 4 Coefficient': 184.567140522253, 'TOD 5 Coefficient': 148.415986401768, 'TOD 6 Coefficient': 214.263457356341, 'TOD 7 Coefficient': 273.116641138042, 'TOD 8 Coefficient': 182.957575809464, 'TOD 9 Coefficient': 91.0685791954417, 'WEEKEND Coefficient': -74.4380968181016, 'BuildingName': 'ARC', 'CAAN': 4799.0, 'Construction Date': '04/15/2002', 'Display Name': 'Activities and Recreation Center', 'Latitude': 38.5428969596, 'Longitude': -121.759644393, 'Maintained Gross Sq. Ft.': 158120.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [9] Activities and Recreation Center | Baseline Electricity
#   {'Building Name': 'ARC', 'CDD Coefficient': 4.34, 'CDD^2 Coefficient': 0.0, 'HDD Coefficient': -1.33, 'HDD^2 Coefficient': 0.16, 'Intercept Coefficient': 620.19, 'MONTH 1 Coefficient': 163.77, 'MONTH 10 Coefficient': 139.9, 'MONTH 11 Coefficient': 47.64, 'MONTH 2 Coefficient': 161.35, 'MONTH 3 Coefficient': 147.41, 'MONTH 4 Coefficient': 169.44, 'MONTH 5 Coefficient': 150.84, 'MONTH 6 Coefficient': 133.63, 'MONTH 7 Coefficient': 80.5, 'MONTH 8 Coefficient': 104.99, 'MONTH 9 Coefficient': 121.97, 'Outlier High': '', 'Outlier Low': '', 'Predicted EUI': '', 'Predicted EUI Outlier High': '', 'Predicted EUI Outlier Low': '', 'TOD 0 Coefficient': -77.01, 'TOD 1 Coefficient': -157.96, 'TOD 10 Coefficient': 110.7, 'TOD 11 Coefficient': 108.1, 'TOD 12 Coefficient': 105.82, 'TOD 13 Coefficient': 101.52, 'TOD 14 Coefficient': 100.83, 'TOD 15 Coefficient': 105.45, 'TOD 16 Coefficient': 114.04, 'TOD 17 Coefficient': 113.93, 'TOD 18 Coefficient': 107.88, 'TOD 19 Coefficient': 114.65, 'TOD 2 Coefficient': -221.53, 'TOD 20 Coefficient': 116.33, 'TOD 21 Coefficient': 80.32, 'TOD 22 Coefficient': 51.68, 'TOD 3 Coefficient': -178.76, 'TOD 4 Coefficient': -168.65, 'TOD 5 Coefficient': 16.65, 'TOD 6 Coefficient': 28.37, 'TOD 7 Coefficient': 80.03, 'TOD 8 Coefficient': 91.87, 'TOD 9 Coefficient': 109.5, 'WEEKEND Coefficient': -108.82, 'BuildingName': 'ARC', 'CAAN': 4799.0, 'Construction Date': '04/15/2002', 'Display Name': 'Activities and Recreation Center', 'Latitude': 38.5428969596, 'Longitude': -121.759644393, 'Maintained Gross Sq. Ft.': 158120.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [10] Activities and Recreation Center | Baseline Steam
#   {'Building Name': 'ARC', 'CDD Coefficient': -10.3621064095358, 'CDD^2 Coefficient': 0.155424888734635, 'HDD Coefficient': 72.0393317038687, 'HDD^2 Coefficient': -0.239799824795194, 'Intercept Coefficient': 310.5633276, 'MONTH 1 Coefficient': 35.4599949855163, 'MONTH 10 Coefficient': -132.730038218068, 'MONTH 11 Coefficient': 89.4240323754714, 'MONTH 2 Coefficient': 109.966602772471, 'MONTH 3 Coefficient': 93.1068697396952, 'MONTH 4 Coefficient': 30.9741507877872, 'MONTH 5 Coefficient': -115.219692342957, 'MONTH 6 Coefficient': -206.580611574226, 'MONTH 7 Coefficient': -48.7240461982951, 'MONTH 8 Coefficient': 2.89607801212689, 'MONTH 9 Coefficient': -1.86116045069572, 'Outlier High': 0.0, 'Outlier Low': 0.0, 'Predicted EUI': 0.0, 'Predicted EUI Outlier High': 0.0, 'Predicted EUI Outlier Low': 0.0, 'TOD 0 Coefficient': -97.4602106454432, 'TOD 1 Coefficient': -193.325051154164, 'TOD 10 Coefficient': -278.230319472735, 'TOD 11 Coefficient': 4.65761816531612, 'TOD 12 Coefficient': 97.5956450797199, 'TOD 13 Coefficient': 411.078215249575, 'TOD 14 Coefficient': 415.701371088456, 'TOD 15 Coefficient': 350.966096702944, 'TOD 16 Coefficient': 208.190218099798, 'TOD 17 Coefficient': 127.005505676255, 'TOD 18 Coefficient': 71.2628205871708, 'TOD 19 Coefficient': 28.9572822010552, 'TOD 2 Coefficient': 13.636556187142, 'TOD 20 Coefficient': 1.29793285554961, 'TOD 21 Coefficient': -8.15456360906919, 'TOD 22 Coefficient': -8.80143345044467, 'TOD 3 Coefficient': -10.7819198494613, 'TOD 4 Coefficient': 6.56849328957835, 'TOD 5 Coefficient': 17.4689534398221, 'TOD 6 Coefficient': 37.0116916527428, 'TOD 7 Coefficient': 52.2732435416744, 'TOD 8 Coefficient': 64.6842817402819, 'TOD 9 Coefficient': 36.8939031095058, 'WEEKEND Coefficient': -44.203438376012, 'BuildingName': 'ARC', 'CAAN': 4799.0, 'Construction Date': '04/15/2002', 'Display Name': 'Activities and Recreation Center', 'Latitude': 38.5428969596, 'Longitude': -121.759644393, 'Maintained Gross Sq. Ft.': 158120.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [11] Activities and Recreation Center | ChilledWater
#   {'Annual Cost': 111946.0, 'BuildingName': 'ARC', 'Prefix': 'Activities_and_Recreation_Center_Flexim', 'Rollover': 0.0, 'Rollover Count Month': 0.0, 'Rollover Count Year': 0.0, 'tonh Rate': 0.1493, 'CAAN': 4799.0, 'Construction Date': '04/15/2002', 'Display Name': 'Activities and Recreation Center', 'Latitude': 38.5428969596, 'Longitude': -121.759644393, 'Maintained Gross Sq. Ft.': 158120.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [12] Activities and Recreation Center | Electricity
#   {'Annual Cost': 151156.0, 'BuildingName': 'ARC', 'kWh Rate': 0.0687, 'Prefix': 'Activities_and_Recreation_Center_MSB', 'Rollover': 10000000.0, 'CAAN': 4799.0, 'Construction Date': '04/15/2002', 'Display Name': 'Activities and Recreation Center', 'Latitude': 38.5428969596, 'Longitude': -121.759644393, 'Maintained Gross Sq. Ft.': 158120.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
# [13] Activities and Recreation Center | Steam
#   {'Annual Cost': 46360.0, 'BuildingName': 'ARC', 'klb Rate': 7.2552, 'Prefix': 'Activities_and_Recreation_Center_MSB', 'Rollover': 100000.0, 'Rollover Count Month': 0.0, 'Rollover Count Year': 0.0, 'CAAN': 4799.0, 'Construction Date': '04/15/2002', 'Display Name': 'Activities and Recreation Center', 'Latitude': 38.5428969596, 'Longitude': -121.759644393, 'Maintained Gross Sq. Ft.': 158120.0, 'Primary Usage (Type)': 'REC - Athletics & Recreation'}
# ------------------------
